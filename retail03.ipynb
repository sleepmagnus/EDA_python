# %%
import pandas as pd
import numpy as np

# %%
df0 = pd.read_csv('online_retail.csv', encoding='latin-1')  
df0.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
# estudiando que datos tengo
df0.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
df0.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
df0['Country'].value_counts()
# Out:
# Country
# United Kingdom          495478
# Germany                   9495
# France                    8557
# EIRE                      8196
# Spain                     2533
# Netherlands               2371
# Belgium                   2069
# Switzerland               2002
# Portugal                  1519
# Australia                 1259
# Norway                    1086
# Italy                      803
# Channel Islands            758
# Finland                    695
# Cyprus                     622
# Sweden                     462
# Unspecified                446
# Austria                    401
# Denmark                    389
# Japan                      358
# Poland                     341
# Israel                     297
# USA                        291
# Hong Kong                  288
# Singapore                  229
# Iceland                    182
# Canada                     151
# Greece                     146
# Malta                      127
# United Arab Emirates        68
# ...

# %%
df0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
df0['InvoiceDate'].head()
# Out:
# 0    12/1/2010 8:26
# 1    12/1/2010 8:26
# 2    12/1/2010 8:26
# 3    12/1/2010 8:26
# 4    12/1/2010 8:26
# Name: InvoiceDate, dtype: object

# %%
df0['InvoiceDate'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 541909 entries, 0 to 541908
# Series name: InvoiceDate
# Non-Null Count   Dtype
# --------------   -----
# 541909 non-null  object
# dtypes: object(1)
# memory usage: 4.1+ MB

# %%
df0['InvoiceDate'].describe()
# Out:
# count               541909
# unique               23260
# top       10/31/2011 14:41
# freq                  1114
# Name: InvoiceDate, dtype: object

# %%
df0['InvoiceNo'].describe()
# Out:
# count     541909
# unique     25900
# top       573585
# freq        1114
# Name: InvoiceNo, dtype: object

# %%
df0.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
df0.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
# analizando cuantos datos tengo en el InvoiceNo que comienzan con C
df0nombres_con_c = df0[df0['InvoiceNo'].str.startswith('C')]
df0nombres_con_c
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 141      C536379         D                          Discount        -1
# 154      C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235      C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236      C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237      C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
# ...          ...       ...                               ...       ...
# 540449   C581490     23144   ZINC T-LIGHT HOLDER STARS SMALL       -11
# 541541   C581499         M                            Manual        -1
# 541715   C581568     21258        VICTORIAN SEWING BOX LARGE        -5
# 541716   C581569     84978  HANGING HEART JAR T-LIGHT HOLDER        -1
# 541717   C581569     20979     36 PENCILS TUBE RED RETROSPOT        -5
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
# son muy pocos, asi que los eliminamos
dfinvoiceint = df0[~df0['InvoiceNo'].str.startswith('C')]

# %%
dfinvoiceint.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 532621 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    532621 non-null  object
#  1   StockCode    532621 non-null  object
#  2   Description  531167 non-null  object
#  3   Quantity     532621 non-null  int64
#  4   InvoiceDate  532621 non-null  object
#  5   UnitPrice    532621 non-null  float64
#  6   CustomerID   397924 non-null  float64
#  7   Country      532621 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 36.6+ MB

# %%
# analizando que otros valores con letras tenemos

# %%
df0nombres_con_aoc = df0[df0['InvoiceNo'].str.match('^[AC]')]
df0nombres_con_aoc
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 141      C536379         D                          Discount        -1
# 154      C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235      C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236      C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237      C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
# ...          ...       ...                               ...       ...
# 540449   C581490     23144   ZINC T-LIGHT HOLDER STARS SMALL       -11
# 541541   C581499         M                            Manual        -1
# 541715   C581568     21258        VICTORIAN SEWING BOX LARGE        -5
# 541716   C581569     84978  HANGING HEART JAR T-LIGHT HOLDER        -1
# 541717   C581569     20979     36 PENCILS TUBE RED RETROSPOT        -5
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
# sacamos todos los valores que empiecen por A o C en la columna del InvoiceNo, de tal manera que pueda ser entero
dfinvoiceint =  df0[~df0['InvoiceNo'].str.match('^[AC]')]

# %%
dfinvoiceint.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  532618.000000  532618.000000  397924.000000
# mean       10.240024       3.868412   15294.315171
# std       159.593999      32.470442    1713.169877
# min     -9600.000000       0.000000   12346.000000
# 25%         1.000000       1.250000   13969.000000
# 50%         3.000000       2.080000   15159.000000
# 75%        10.000000       4.130000   16795.000000
# max     80995.000000   13541.330000   18287.000000

# %%
dfinvoiceint['InvoiceNo'] = dfinvoiceint['InvoiceNo'].astype(int)
# Out:
# C:\Users\diego\AppData\Local\Temp\ipykernel_11628\3897783455.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfinvoiceint['InvoiceNo'] = dfinvoiceint['InvoiceNo'].astype(int)

# %%
dfinvoiceint['InvoiceNo']
# Out:
# 0         536365
# 1         536365
# 2         536365
# 3         536365
# 4         536365
#            ...
# 541904    581587
# 541905    581587
# 541906    581587
# 541907    581587
# 541908    581587
# Name: InvoiceNo, Length: 532618, dtype: int32

# %%
dfinvoiceint['CustomerID'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0         17850.0
# 1         17850.0
# 2         17850.0
# 3         17850.0
# 4         17850.0
#            ...
# 541904    12680.0
# 541905    12680.0
# 541906    12680.0
# 541907    12680.0
# 541908    12680.0
# Name: CustomerID, Length: 532618, dtype: float64>

# %%
dfcountries = dfinvoiceint['Country'].unique()

# %%
len(dfcountries)
# Out:
# 38

# %%
dfcountries
# Out:
# array(['United Kingdom', 'France', 'Australia', 'Netherlands', 'Germany',
#        'Norway', 'EIRE', 'Switzerland', 'Spain', 'Poland', 'Portugal',
#        'Italy', 'Belgium', 'Lithuania', 'Japan', 'Iceland',
#        'Channel Islands', 'Denmark', 'Cyprus', 'Sweden', 'Finland',
#        'Austria', 'Bahrain', 'Israel', 'Greece', 'Hong Kong', 'Singapore',
#        'Lebanon', 'United Arab Emirates', 'Saudi Arabia',
#        'Czech Republic', 'Canada', 'Unspecified', 'Brazil', 'USA',
#        'European Community', 'Malta', 'RSA'], dtype=object)

# %%
# hay pocos casos donde no se especifica el pais, asi que removere esas filas
dfinvoiceint[dfinvoiceint['Country'] == 'Unspecified']
# Out:
#         InvoiceNo StockCode                          Description  Quantity  \
# 152712     549687     20685                DOORMAT RED RETROSPOT         2
# 152713     549687     22691              DOORMAT WELCOME SUNRISE         2
# 152714     549687     48116           DOORMAT MULTICOLOUR STRIPE         2
# 152715     549687     21213          PACK OF 72 SKULL CAKE CASES        24
# 152716     549687     21977   PACK OF 60 PINK PAISLEY CAKE CASES        24
# ...           ...       ...                                  ...       ...
# 498778     578539     22560           TRADITIONAL MODELLING CLAY        24
# 498779     578539     23570     TRADITIONAL PICK UP STICKS GAME         12
# 498780     578539     23571        TRADITIONAL NAUGHTS & CROSSES        12
# 498781     578539     84992       72 SWEETHEART FAIRY CAKE CASES        24
# 498782     578539     23309  SET OF 60 I LOVE LONDON CAKE CASES         24
#
#              InvoiceDate  UnitPrice  CustomerID      Country
# ...

# %%
# hago una copia del data frame donde borrare esos datos
dfinvoiceint2 = dfinvoiceint

# %%
dfinvoiceint2 = dfinvoiceint[(dfinvoiceint['Country'] != 'Unspecified')]

# %%
# data frame con los paises sin especificar
dfinvoiceint
# Out:
#         InvoiceNo StockCode                          Description  Quantity  \
# 0          536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1          536365     71053                  WHITE METAL LANTERN         6
# 2          536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3          536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4          536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...           ...       ...                                  ...       ...
# 541904     581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905     581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906     581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907     581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908     581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
# data frame nuevo SIN los paises sin ser especificados
dfinvoiceint2
# Out:
#         InvoiceNo StockCode                          Description  Quantity  \
# 0          536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1          536365     71053                  WHITE METAL LANTERN         6
# 2          536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3          536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4          536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...           ...       ...                                  ...       ...
# 541904     581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905     581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906     581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907     581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908     581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
# viendo que valores nulos tenemos en el data frame para deshacerme de ellos
print(dfinvoiceint2.isnull().sum())
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     134492
# Country             0
# dtype: int64

# %%
dfinvoiceint3 = dfinvoiceint2.copy()

# %%
dfinvoiceint3.head()
# Out:
#    InvoiceNo StockCode                          Description  Quantity  \
# 0     536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365     71053                  WHITE METAL LANTERN         6
# 2     536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3     536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4     536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
# quitando los valores de descrpition que tienen valores nulos
dfinvoiceint3.dropna(subset=['Description'], inplace=True)

# %%
dfinvoiceint3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 530718 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    530718 non-null  int32
#  1   StockCode    530718 non-null  object
#  2   Description  530718 non-null  object
#  3   Quantity     530718 non-null  int64
#  4   InvoiceDate  530718 non-null  object
#  5   UnitPrice    530718 non-null  float64
#  6   CustomerID   397680 non-null  float64
#  7   Country      530718 non-null  object
# dtypes: float64(2), int32(1), int64(1), object(4)
# memory usage: 34.4+ MB

# %%
# ahora el que nos quedan son el monton de datos nulos del customerID que no tienen valores, que se puede hacer? primero estudiamos un poco que tenemos
dfinvoiceint3['CustomerID'].isna().sum()
# Out:
# 133038

# %%
dfinvoiceint3.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
dfinvoiceint3['InvoiceDate'].head()
# Out:
# 0    12/1/2010 8:26
# 1    12/1/2010 8:26
# 2    12/1/2010 8:26
# 3    12/1/2010 8:26
# 4    12/1/2010 8:26
# Name: InvoiceDate, dtype: object

# %%
dfinvoiceint3['InvoiceDate'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 530718 entries, 0 to 541908
# Series name: InvoiceDate
# Non-Null Count   Dtype
# --------------   -----
# 530718 non-null  object
# dtypes: object(1)
# memory usage: 8.1+ MB

# %%
dfinvoiceint3['InvoiceDate'] = pd.to_datetime(dfinvoiceint3['InvoiceDate'], format='%H%M%d/%m/%Y')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[345], line 1
# ----> 1 dfinvoiceint3['InvoiceDate'] = pd.to_datetime(dfinvoiceint3['InvoiceDate'], format='%H%M%d/%m/%Y')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\tools\datetimes.py:1063, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1061             result = arg.tz_localize("utc")
#    1062 elif isinstance(arg, ABCSeries):
# -> 1063     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1064     if not cache_array.empty:
#    1065         result = arg.map(cache_array)
#
# ...
